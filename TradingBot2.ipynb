# %%
import requests
import os
import json
import preprocessor as p #tweetpreprocessor --> https://pypi.org/project/tweet-preprocessor/
from langdetect import detect #https://pypi.org/project/langdetect/
from csv import writer

from ernie import SentenceClassifier #Model importieren
import numpy as np

from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import re
import bs4 as bs
from urllib.request import urlopen
import pandas as pd
import pandas_datareader.data as pdr
from datetime import datetime


BEARER_TOKEN="AAAAAAAAAAAAAAAAAAAAAM4kQAEAAAAAJe3CEuCF2PgbZc7HdJ9bxab8cPc%3D27Wz1OcVdt8S6p2zdjX406RoBIgJ1ctJ0LM736dWCpw9PEnZy6"
classifier = SentenceClassifier(model_path='output')

in_position = False
TRADE_SYMBOL = "BTCUSDT"
TRADE_QUANTITY = 0.005
c=0
sentimentLst = []
in_position = False


def getIndex(): #WebScraper für den Fear & Greed Index
    cnn = "https://money.cnn.com/data/fear-and-greed/"
    req = Request(url=cnn, headers={'user-agent': 'my-app/0.0.1'})
    response = urlopen(req)
    # response
    feargreedindex = {}
    html = BeautifulSoup(response)

    feargreedindex = html.find(id='needleChart')

    dataRows = feargreedindex.findAll('li')
    indexString = dataRows[0]
    indexString = re.findall(r'[0-9]+', str(indexString))
    return float(indexString[0])

def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers


def get_rules(headers, bearer_token):
    response = requests.get(
        "https://api.twitter.com/2/tweets/search/stream/rules", headers=headers
    )
    if response.status_code != 200:
        raise Exception(
            "Cannot get rules (HTTP {}): {}".format(response.status_code, response.text)
        )
    return response.json()


def delete_all_rules(headers, bearer_token, rules):
    if rules is None or "data" not in rules:
        return None

    ids = list(map(lambda rule: rule["id"], rules["data"]))
    payload = {"delete": {"ids": ids}}
    response = requests.post(
        "https://api.twitter.com/2/tweets/search/stream/rules",
        headers=headers,
        json=payload
    )
    if response.status_code != 200:
        raise Exception(
            "Cannot delete rules (HTTP {}): {}".format(
                response.status_code, response.text
            )
        )


def set_rules(headers, delete, bearer_token): #Rules an API senden, um Daten zu empfangen
    #Rules können angepasst werden
    sample_rules = [
        {"value": "#bitcoin", "tag": "bitcoin"},
        # {"value": "cat has:images -grumpy", "tag": "cat pictures"},
    ]
    payload = {"add": sample_rules}
    response = requests.post(
        "https://api.twitter.com/2/tweets/search/stream/rules",
        headers=headers,
        json=payload,
    )
    if response.status_code != 201:
        raise Exception(
            "Cannot add rules (HTTP {}): {}".format(response.status_code, response.text)
        )


def get_stream(headers, set, bearer_token):
    global sentiments,fg_index_d,c
    response = requests.get(
        "https://api.twitter.com/2/tweets/search/stream", headers=headers, stream=True,
    )
    if response.status_code != 200:
        raise Exception(
            "Cannot get stream (HTTP {}): {}".format(
                response.status_code, response.text
            )
        )
    for response_line in response.iter_lines():
        if response_line:
            json_response = json.loads(response_line)
            tweet = json_response['data']['text']
            tweet = p.clean(tweet)
            tweet = tweet.replace(':','')
            index = getIndex()

            try:
                if detect(tweet) == 'en':
                    try: 
                        #-1 BEARISH 0 NEUTRAL 1 BULLISH
                        classes = ["Bearish", "Neutral", "Bullish"]
                        probabilities = classifier.predict_one(tweet)
                        polarity = classes[np.argmax(probabilities)]
                        if c<=15:
                            print('')
                            print(f'{tweet}******** Predicted Sentiment: {polarity} ********')
                            print('')
                            c+=1
                        if polarity=='Neutral':
                            sentiments['Neutral']+=1
                        elif polarity=='Bullish':
                            sentiments['Bullish']+=1
                        elif polarity=='Bearish':
                            sentiments['Bearish']+=1
                        sentimentLst.append(polarity)
                        print(f"******** Live Bullish Tweet Count : {sentiments['Bullish']} ********",end='\r')
                        index = getIndex()
                        if index<=49 and index>=0:
                            fg_index_d['Bearish']+=1
                        elif index>=50 and index<=60:
                            fg_index_d['Neutral']+=1
                        elif index>60:
                            fg_index_d['Bullish']+=1
                        if sentiments['Bullish']==35:
                              print(sentiments['Bullish'])
                              break
                        if len(sentimentLst) > 50:
                            endList = sentimentLst[-50:]
                            # print("******** TOTAL BULLISH: " + str(endList.count('Bullish')))
                            # print("******** TOTAL BEARISH: " + str(endList.count('Bearish')))

                            if endList.count('Bullish') > 40 and index < 40:
                                #BUY
                                if in_position:
                                    print("******** BUY ******** but we own")
                                else: 
                                    print("******** BUY ********")
                                    # order_succeeded = order(SIDE_BUY, TRADE_QUANTITY, TRADE_SYMBOL)
                                    if order_succeeded:
                                        in_position = True
                            elif endList.count('Bearish') > 40 and index > 60:
                                #SELL
                                if in_position:
                                    # order_succeeded = order(SIDE_SELL, TRADE_QUANTITY, TRADE_SYMBOL)
                                    if order_succeded:
                                        in_position = False
                                else:
                                    print('******** SELL ******** but we dont own')
                    except:
                        pass
                    # tweetLst = [tweet]

                    # with open('bitcoindata.csv', 'a+', newline='') as write_obj:
                    #     csv_writer = writer(write_obj)
                    #     csv_writer.writerow(tweetLst)
            except:
                pass
        
sentiments={'Bullish':0,'Bearish':0,'Neutral':0}
fg_index_d={'Bullish':0,'Bearish':0,'Neutral':0}
def main():
    global sentiments,fg_index_d
    try:
        bearer_token = BEARER_TOKEN
        headers = create_headers(bearer_token)
        rules = get_rules(headers, bearer_token)
        delete = delete_all_rules(headers, bearer_token, rules)
        set = set_rules(headers, delete, bearer_token)
        get_stream(headers, set, bearer_token)
    except:
        pass
    print(f"********Current Number of Bullish Tweets: {sentiments['Bullish']}********")
    print(f"******** CNN Fear and Greed Index: {getIndex()} ********")
    
          
      
while True: #News Scraper + Sentiment Analysis 
    main()
    crypto_name='BTC'
    source=urlopen(f'https://news.google.com/search?q={crypto_name}?h%3Den-US&gl=US&ceid=US:en&hl=en-US').read()
    soup = bs.BeautifulSoup(source,'lxml')
    import pysentiment2 as ps
    lm = ps.LM()
    sentiment_d={'Positive':0,'Negative':0}
    lnks=soup.find_all('h3')
    for itert in lnks:
        lnk=itert.find('a').text
        tokens = lm.tokenize(lnk)
        score = lm.get_score(tokens)
        if score['Positive']>0:
            sentiment_d['Positive']+=1
        if score['Negative']>0:
            sentiment_d['Negative']+=1
    
    print(f'******** Total Number of News Crawled: {sum(sentiment_d.values())} ********')
    print(f'******** Sentiment of News: {max(sentiment_d, key=sentiment_d.get)} ********')
    end=datetime.today()
    BTC = pdr.DataReader('BTC-USD','yahoo',datetime(end.year-1,end.month,end.day),end)
    ShortEMA = BTC.Close.ewm(span=12, adjust=False).mean()
    #EMA ausrechnen
    LongEMA = BTC.Close.ewm(span=26, adjust=False).mean()
    #MACD ausrechnen
    MACD = ShortEMA - LongEMA
    #Linie des MACD ausrechnen
    signal = MACD.ewm(span=9, adjust=False).mean() 
    BTC['MACD'] = MACD
    BTC['Signal_Line'] = signal
    macd_signal='Buy'
    if BTC.iloc[-1]['MACD']<0 :
        macd_signal='Sell'
    print(f'******** Current MACD: {macd_signal} ********')
    def computeRSI (data, time_window):
        diff = data.diff(1).dropna()      

     
        up_chg = 0 * diff
        down_chg = 0 * diff


        up_chg[diff > 0] = diff[ diff>0 ]

 
        down_chg[diff < 0] = diff[ diff < 0 ]

        #EMA's kalkulieren
        up_chg_avg   = up_chg.ewm(com=time_window-1 , min_periods=time_window).mean()
        down_chg_avg = down_chg.ewm(com=time_window-1 , min_periods=time_window).mean()

        rs = abs(up_chg_avg/down_chg_avg)
        rsi = 100 - 100/(1+rs)
        return(rsi)

    rsi_list=[]
    for g in computeRSI(BTC['Close'], 14):
        if str(g)!='nan':
            rsi_list.append(g)

    rsi_indicator=''
    if rsi_list[-1]>70:
        rsi_indicator='Sell'
    elif rsi_list[-1]<30:
        rsi_indicator='Buy'
    else:
        rsi_indicator='Neutral'
    print(f'******** Current RSI: {rsi_indicator} ********')
    tweet_score=(sentiments['Bullish']/sum(sentiments.values()))*100
    news_score=(sentiment_d['Positive']/sum(sentiment_d.values()))*100
    fg_score=(fg_index_d['Bullish']/sum(fg_index_d.values()))*100

    tweet_weightage=30
    news_weightage=40
    fg_score_weightage=30

    #Order Function mit Kauf- und Verkaufsfunktion bei 5% Profit  
    score=tweet_score*(tweet_weightage/100)+news_score*(news_weightage/100)+fg_score*(fg_score_weightage/100)
    if score>80:
        print(f'******** CURRENT OVERALL SCORE : {score} ***** Waiting to set the Buy Order..')
    else:
        print(f'******** CURRENT OVERALL SCORE : {score} *****')

    try:
        from binance.enums import *
        from binance.client import Client
        import binance

        if score > 80:
            client = Client('','')

            stop_loss=float(client.get_avg_price(symbol='BTCUSDT')['price']) - (float(client.get_avg_price(symbol='BTCUSDT')['price'])*0.05)
            avg_price = client.get_avg_price(symbol='BTCUSDT')['price']
            print(stop_loss,avg_price)

            order = client.order_market_buy(symbol='BTCUSDT',quantity=0.001)
            print(f"******** BTC BOUGHT AT : {avg_price} WITH STOP LOSS AT :{stop_loss} ******* Waiting for Sell")

            while True:
              current_price = client.get_avg_price(symbol='BTCUSDT')['price']
              if float(current_price)>float(stop_loss) and float(current_price) < (float(avg_price) + (float(avg_price)*0.005)):
                print(f"Price : {client.get_avg_price(symbol='BTCUSDT')['price']} Stop Loss {stop_loss}")
                pass
              else:
                order = client.order_market_sell(symbol='BTCUSDT',quantity=0.001)
                if stop_loss>current_price:
                      print('***** Stop Loss Hit ***** Sold')
                elif float(current_price) >= (float(avg_price) + (float(avg_price)*0.005)):
                      print(f'****** BTC SOLD *** Your profit is {current_price-avg_price} USD ****')
                break
    except:
         pass
    c=0
    sentiments={'Bullish':0,'Bearish':0,'Neutral':0}
    fg_index_d={'Bullish':0,'Bearish':0,'Neutral':0}
# Out:
#  New airdrop MoonLift (MLTP)Total Reward $2,000 of MLTPRate Market Lbank,Bilaxy,Pancakeswap,Coinmarketcap******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 0 ********
#  $ || PHP || IDR Giveaway- Retweet And Follow End In Hours Goodluck******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 0 ********
#  Paraguay announces a bill that would make legal tender and also to encourage mining (with renewable energy sources).******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 1 ********
#  Spains BBVA went LIVE this week with trading available to all clients in Switzerland.******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 1 ********
#  New  DeFiFarms Reward Up to DEFIY [~$2.2]+3 DEFIY [$0.3] per referral Start the airdrop bot******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 1 ********
#  New airdrop MoonLift (MLTP)Total Reward $2,000 of MLTPRate Market Lbank,Bilaxy,Pancakeswap,Coinmarketcap******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 1 ********
#  Dogecoin $20K airdrop! Total reward K DOGE2 tokens Easy social tasks Trade any amount of tokens to earn rewa******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 1 ********
#  I will send one random person $100 all you have to do is RT and like quoted tweet Short the "*ankers"Long******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 1 ********
# X2P is the best crypto token which is very stable through all market crashes and given x to x returns.We just cut a zero and reached ATH just weeks after launching Trust the process******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 1 ********
#  Unlike the dollar, empowers the individual - the state.******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 2 ********
# Buy Your Bag of $BUY in dip, Bullrun will Coming Soon The moon Soon******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 2 ********
# He doesn't understand how Bitcoin works. Literally not on any level. His assertions are random and absurd.Travel costs? What planet is he living on that you need to travel to receive/spend btc?He does know how to format a document though!******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 3 ********
#  Spains BBVA went LIVE this week with trading available to all clients in Switzerland.******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
# Just received MATIC tokens in my Coinbase akk Thank you so much ! We are with you!******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
#  New airdrop MoonLift (MLTP)Total Reward $2,000 of MLTPRate Market Lbank,Bilaxy,Pancakeswap,Coinmarketcap******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
#  New  DeFiFarms Reward Up to DEFIY [~$2.2]+3 DEFIY [$0.3] per referral Start the airdrop bot******** Predicted Sentiment: Neutral ********
#
# 35****** Live Bullish Tweet Count : 35 ********
# ********Current Number of Bullish Tweets: 35********
# ******** CNN Fear and Greed Index: 44.0 ********
# ******** Total Number of News Crawled: 39 ********
# ******** Sentiment of News: Negative ********
# ******** Current MACD: Sell ********
# ******** Current RSI: Neutral ********
# ******** CURRENT OVERALL SCORE : 26.410256410256412 *****
#
# I send and got back !!! ETH! It took around sec$doge $btc //******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 0 ********
# Thanks for giving us such a great opportunity. I am supporting it. always success for the development team******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 0 ********
#  JUST IN Tanzania's central bank confirmed today it is investigating and cryptocurrency at the request of Pr******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 1 ********
# "they"******** Predicted Sentiment: Bearish ********
#
# ******** Live Bullish Tweet Count : 1 ********
#  $btc I placed the March dump on the current price...Thoughts?******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 2 ********
#  New  NFTL by CyberTime Total reward Up to NFTL + NFT Visit the Airdrop Page******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 2 ********
# This is definitely going to be HUGE! as the team has been an inspiration in their innovative approaches towards achieving the project goals and visions , I am so glad to be part of this.******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 2 ********
# Weak hands selling. Crypto is not for everyone! If you can't handle drop, go get a job at fucking McDonald's you shrimps!******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 3 ********
# promote this on******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
# Can anyone tell me about matic coin? What's the predictions******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
#  Youve got the we want to see, drop your hottest new now!!Retweet and follow to show support! ALL followers get fo******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
# Join the crypto group******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
#  Airdrop now has been started!How to join?Like, Follow, Retweet &amp; Tag Friends with hashtags******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
# Here is my first collection.******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 4 ********
#  New  DeFiFarms Reward Up to DEFIY [~$2.2]+3 DEFIY [$0.3] per referral Start the airdrop bot******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 4 ********
#  New airdrop MoonLift (MLTP)Total Reward $2,000 of MLTPRate Market Lbank,Bilaxy,Pancakeswap,Coinmarketcap******** Predicted Sentiment: Neutral ********
#
# 35****** Live Bullish Tweet Count : 35 ********
# ********Current Number of Bullish Tweets: 35********
# ******** CNN Fear and Greed Index: 44.0 ********
# ******** Total Number of News Crawled: 39 ********
# ******** Sentiment of News: Negative ********
# ******** Current MACD: Sell ********
# ******** Current RSI: Neutral ********
# ******** CURRENT OVERALL SCORE : 24.882705946535737 *****
#
#  New airdrop MoonLift (MLTP)Total Reward $2,000 of MLTPRate Market Lbank,Bilaxy,Pancakeswap,Coinmarketcap******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 0 ********
#  Here come the to $5,000 tweet.******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 0 ********
#  New airdrop MoonLift (MLTP)Total Reward $2,000 of MLTPRate Market Lbank,Bilaxy,Pancakeswap,Coinmarketcap******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 0 ********
# Join the crypto group******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 0 ********
#  K away x $50 BUSD!!Drawn in daysDont we all want free money! Follow******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 0 ********
#  Spains BBVA went LIVE this week with trading available to all clients in Switzerland.******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 0 ********
#  Sanctuary Token Airdrop Task Up to155 SNT (~$10) Referral SNT (~$2) Airdrop Link******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 0 ********
# $cava will change lives. Today live on******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 0 ********
#  Check out last week's Top Trending Tokens in EUROPE! Add them to your portfolio and have the latest price movements******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 0 ********
#  PUPPYDOGE PRE-SALE GIVEAWAY!Top prize .5 BTC (Bitcoin)Second prize x Oculus Quest ($300 value)Third pr******** Predicted Sentiment: Neutral ********
# ******** Live Bullish Tweet Count : 0 ********
#  Sanctuary Token Airdrop Task Up to155 SNT (~$10) Referral SNT (~$2) Airdrop Link******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 0 ********
# James I would seriously consider Cardano. Binance is doing well because of ethereums high gas fees. Once cardano goes live in September Binance will drop and go back to being a exchange. Just be careful******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 1 ********
# Sir im with you******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 1 ********
#  For those who are too scared to buy cryptocurrency, try it on LATOKEN app. They provide daily promos from which you can******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 1 ********
#  New airdrop Kephi Gallery (KPHI)Total Reward KPHIReward Stakes/PointsRate Distribution afte******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 1 ********
#  Still worried about going to zero?Relax and think. It won't. On top of many other reasons, it is now legal tende******** Predicted Sentiment: Bullish ********
#
# 35****** Live Bullish Tweet Count : 35 ********
# ********Current Number of Bullish Tweets: 35********
# ******** CNN Fear and Greed Index: 44.0 ********
# ******** Total Number of News Crawled:
** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 4 ********
# You can't stop the network.******** Predicted Sentiment: Bearish ********
#
# ******** Live Bullish Tweet Count : 4 ********
#  If you want to give joy to billion people you need digital music. If you want to give knowledge to billion people y******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 5 ********
#  PUPPYDOGE PRE-SALE GIVEAWAY!Top prize .5 BTC (Bitcoin)Second prize x Oculus Quest ($300 value)Third pr******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 5 ********
#  Sanctuary Token Airdrop Task Up to155 SNT (~$10) Referral SNT (~$2) Airdrop Link******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 5 ********
# testing new Airdrop good morning******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 5 ********
# An amazing team here congratulations to us for early abduction. Join guys $BERRY******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 5 ********
#  Still worried about going to zero?Relax and think. It won't. On top of many other reasons, it is now legal tende******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 6 ********
#  for all who want to try out the public beta wallets (1.14.3) they are available from here back******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 6 ********
#  Spains BBVA went LIVE this week with trading available to all clients in Switzerland.******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 6 ********
# Oh stop, you know what Wyckoff Accumulation is. Yall are the same age.******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 7 ********
#  We heard you you want to put the on 's Rally here Get $******** Predicted Sentiment: Neutral ********
#
# 35****** Live Bullish Tweet Count : 35 ********
# ********Current Number of Bullish Tweets: 35********
# ******** CNN Fear and Greed Index: 44.0 ********
# ******** Total Number of News Crawled: 38 ********
# ******** Sentiment of News: Negative ********
# ******** Current MACD: Sell ********
# ******** Current RSI: Neutral ********
# ******** CURRENT OVERALL SCORE : 25.740410347903655 *****
#
#  Check out they are building decentralized finance on with the $DFI token!1year old, MainNet up &amp; runnin******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 0 ********
#  if 00 a.m. GMT-4 is more than $27980 then sell.******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 1 ********
# You forgot NFA. So I can sue.******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 2 ********
#  Still worried about going to zero?Relax and think. It won't. On top of many other reasons, it is now legal tende******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 3 ********
#  I beg you in the name of God kindly retweet pleaseShoes k eachCaps k eachAvailable only on pre orderLocation Kad******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
#  New airdrop MoonLift (MLTP)Total Reward $2,000 of MLTPRate Market Lbank,Bilaxy,Pancakeswap,Coinmarketcap******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
#  New airdrop MoonLift (MLTP)Total Reward $2,000 of MLTPRate Market Lbank,Bilaxy,Pancakeswap,Coinmarketcap******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
#  I will be listing my first ever NFT on as /1 painting. Stay tuned and follow.******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
# is the bottom (-85% from ath as usual). Im saying this since March.******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
#  New airdrop MoonLift (MLTP)Total Reward $2,000 of MLTPRate Market Lbank,Bilaxy,Pancakeswap,Coinmarketcap******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
#  New airdrop MoonLift (MLTP)Total Reward $2,000 of MLTPRate Market Lbank,Bilaxy,Pancakeswap,Coinmarketcap******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
#  I beg you in the name of God kindly retweet pleaseShoes k eachCaps k eachAvailable only on pre orderLocation Kad******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
#  El Salvador Paraguay BrazilIn year ten other countries will have as legal tender...******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 4 ********
# Great Airdrop******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 5 ********
#  New airdrop MoonLift (MLTP)Total Reward $2,000 of MLTPRate Market Lbank,Bilaxy,Pancakeswap,Coinmarketcap******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 5 ********
# Instead of your cryptocurrency lying around uselessly,it can work for you and multiply,through staking,liquidity mining.If you use my link you will get a $30 bonus.Just start small and let yourself be convinced. contact me for help.(no financial advice)******** Predicted Sentiment: Neutral ********
#
# 35****** Live Bullish Tweet Count : 35 ********
# ********Current Number of Bullish Tweets: 35********
# ******** CNN Fear and Greed Index: 44.0 ********
# ******** Total Number of News Crawled: 39 ********
# ******** Sentiment of News: Negative ********
# ******** Current MACD: Sell ********
# ******** Current RSI: Neutral ********
# ******** CURRENT OVERALL SCORE : 24.627678257815244 *****
#
# That could be called "Swiss train model" because the train goes up faster without unnecessary passengers******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 0 ********
#  GIVEAWAY ($7k value) CryptoGvng Launching1.) Retweet &amp; Follow2.) Join Discord Server  winne******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 0 ********
#  GEM SPOTTED WeRise $WISE Contract x0c24bb9e12a2922c831936199d7c8e24f12b10cbMarketCap $360KLiquidity******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 0 ********
#  .. ! https//******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 0 ********
#  New airdrop MoonLift (MLTP)Total Reward $2,000 of MLTPRate Market Lbank,Bilaxy,Pancakeswap,Coinmarketcap******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 0 ********
# this man know something buy the DIP******** Predicted Sentiment: Bullish ********
# ******** Live Bullish Tweet Count : 1 ********
# is supreme******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 2 ********
# very interesting project I like your project, I hope the project you run is successful and successful******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 2 ********
#  New airdrop MoonLift (MLTP)Total Reward $2,000 of MLTPRate Market Lbank,Bilaxy,Pancakeswap,Coinmarketcap******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 2 ********
#  New airdrop MoonLift (MLTP)Total Reward $2,000 of MLTPRate Market Lbank,Bilaxy,Pancakeswap,Coinmarketcap******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 2 ********
# Want to know what people are tweeting about right now? $AMC$SOL$AAPL$DASH$GME$SPCECheck out to see what else is hot on******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 2 ********
#  The purpose of the dip is to shake out as many people as possible before we go higher******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 2 ********
#  Sanctuary Token Airdrop Task Up to155 SNT (~$10) Referral SNT (~$2) Airdrop Link******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 2 ********
# My biggest fear is not that Bitcoin will go down my biggest fear is that I won't have more Fiat to buy******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 3 ********
# Just earn BTC from this platform and Im still hodling.******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
#  Still worried about going to zero?Relax and think. It won't. On top of many other reasons, it is now legal tende******** Predicted Sentiment: Bullish ********
#
# 35****** Live Bullish Tweet Count : 35 ********
# ********Current Number of Bullish Tweets: 35********
# ******** CNN Fear and Greed Index: 44.0 ********
# ******** Total Number of News Crawled: 39 ********
# ******** Sentiment of News: Negative ********
# ******** Current MACD: Sell ********
# ******** Current RSI: Neutral ********
# ******** CURRENT OVERALL SCORE : 27.34155781325593 *****
#
#  K away x $50 BUSD!!Drawn in daysDont we all want free money! Follow******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 0 ********
# got my certificate from this person in $5******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 1 ********
#  New airdrop DDEX (DDX)Total Reward DDXRate Distribution from th JuneBot Airdrop Link https/******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 1 ********
#  New airdrop MoonLift (MLTP)Total Reward $2,000 of MLTPRate Market Lbank,Bilaxy,Pancakeswap,Coinmarketcap******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 1 ********
# U think there wont be alts season since btc rally wont happen till November******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 1 ********
#
** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 1 ********
#  If you want to give joy to billion people you need digital music. If you want to give knowledge to billion people y******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 2 ********
#  K away x $50 BUSD!!Drawn in daysDont we all want free money! Follow******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 2 ********
#  New airdrop MoonLift (MLTP)Total Reward $2,000 of MLTPRate Market Lbank,Bilaxy,Pancakeswap,Coinmarketcap******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 2 ********
# ...
#
# ******** Live Bullish Tweet Count : 0 ********
# on purchases over $25 at******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 1 ********
#  How is it that dumps quickly at a certain time? Its as if its coordinated. Well Im still accumulating******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 2 ********
#  New airdrop MoonLift (MLTP)Total Reward $2,000 of MLTPRate Market Lbank,Bilaxy,Pancakeswap,Coinmarketcap******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 2 ********
# Check my website for******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 2 ********
#  Losing it at the Luna PR office.******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 3 ********
# Join the crypto group******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
# has agreed to discuss at an upcoming conference.******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
# Shop &amp;******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
#  New airdrop MoonLift (MLTP)Total Reward $2,000 of MLTPRate Market Lbank,Bilaxy,Pancakeswap,Coinmarketcap******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
# Enjoy $10 off Orders of $50+ - Use code IR10 -******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
#  Heres an interesting article from magazine stating that will run wild starting in July. This is based******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
#  ATMs will be installed in El Salvador This country is really making big moves!******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 4 ********
#  _Man_WithNoName******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 4 ********
# Maybe a morning bacardi will soften your feelings******** Predicted Sentiment: Bearish ********
#
# ******** Live Bullish Tweet Count : 4 ********
#  And you will benefit greatly. is more than a savings tool. is allot of different things to di******** Predicted Sentiment: Bullish ********
#
# 35****** Live Bullish Tweet Count : 35 ********
# ********Current Number of Bullish Tweets: 35********
# ******** CNN Fear and Greed Index: 44.0 ********
# ******** Total Number of News Crawled: 38 ********
# ******** Sentiment of News: Negative ********
# ******** Current MACD: Sell ********
# ******** Current RSI: Neutral ********
# ******** CURRENT OVERALL SCORE : 28.132427843803054 *****
#
# I have participated in following the guidelines and rules of this airdrop, i hope that many people will be lucky to get a prize from this airdrop******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 0 ********
#  We are going to be poor Thanks******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 1 ********
#  The more the support is touched, the weaker is gets. For now we seems to be stuck between the .5 and the .618 on $BTC. Let's******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 1 ********
#  And thats why we have******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 2 ********
# The purpose of the dip is to shake out as many people as possible before we go higher. I will advise you to use this opportunity to invest. Thanks to for his guide,mentorship, tips,tweets on how to profit from using an automatic trading and mining platform******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 2 ********
#  Sanctuary Token Airdrop Task Up to155 SNT (~$10) Referral SNT (~$2) Airdrop Link******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 2 ********
# BTC is being marketed by clueless shills.******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 3 ********
# Good News! XRPI Announces XRP Giveaway******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
#  Heres an interesting article from magazine stating that will run wild starting in July. This is based******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
# It's $PTF Power Trade Fuel TokenWith its Amplified Pools Liquidity providers can customize the price curve in advance to create amplified pools that greatly improve capital efficiency and reduce trade slippage.******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
#  Check out last week's Top Trending Thanks for giving us such a great opportunity.******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
#  BULLWHALE! just LONGED $3,643,254 worth of at $31,788 on Futures******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 4 ********
#  Sanctuary Token Airdrop Task Up to155 SNT (~$10) Referral SNT (~$2) Airdrop Link******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 4 ********
#  New airdrop MoonLift (MLTP)Total Reward $2,000 of MLTPRate Market Lbank,Bilaxy,Pancakeswap,Coinmarketcap******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 4 ********
#  Sanctuary Token Airdrop Task Up to155 SNT (~$10) Referral SNT (~$2) Airdrop Link******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 4 ********
#  closing in on $31k. I suppose that must mean it is time to moon again******** Predicted Sentiment: Bullish ********
#
# 35****** Live Bullish Tweet Count : 35 ********
# ********Current Number of Bullish Tweets: 35********
# ******** CNN Fear and Greed Index: 44.0 ********
# ******** Total Number of News Crawled: 39 ********
# ******** Sentiment of News: Negative ********
# ******** Current MACD: Sell ********
# ******** Current RSI: Neutral ********
# ******** CURRENT OVERALL SCORE : 29.645199761478832 *****
#
#  New airdrop MoonLift (MLTP)Total Reward $2,000 of MLTPRate Market Lbank,Bilaxy,Pancakeswap,Coinmarketcap******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 0 ********
#  The HOW TO OCSC DEMO via******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 0 ********
#  HODL with******** Predicted Sentiment: Bearish ********
#
# ******** Live Bullish Tweet Count : 0 ********
#  K away x $50 BUSD!!Drawn in daysDont we all want free money! Follow******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 0 ********
#  New  DeFiFarms Reward Up to DEFIY [~$2.2]+3 DEFIY [$0.3] per referral Start the airdrop bot******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 0 ********
# Start with AI traders .... $AMA******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 0 ********
#  I wish when I was someone told me about and then explained to me, I wouldve been all in. Even if******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 1 ********
# How about on ? Be an early adopter and take a look at the $DFI token from all essential information can be found at******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 1 ********
# Could retest -20k. Most bull runs have retested previous all time highs. You seeing that? Or just fluff?******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 2 ********
# Every investor should put a certain amount into Every bitcoin hodler should put a certain amount into and results speak louder than opinions $DFI******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 3 ********
# is coming dude. Poor your dad******** Predicted Sentiment: Neutral ********
# ******** Live Bullish Tweet Count : 3 ********
# We all know that Bitcoin is secure so why not building decentralized finance on ?$DFI is doing it! Check out for more information ~ Liquidity mining~ Staking~ Great community~ Built on Bitcoindo you really want to miss out this opportunity?******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
#  After straight days of games There's no today Take the opportunity to bet on tomorrow's games******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
# How about on ? Be an early adopter and take a look at the $DFI token from all essential information can be found at******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
# Top100 IN/OUT update in last hours ( )IN $ANKROUT $BAKE******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
# Lesser know asset surges and puts in the shade (temporarily)******** Predicted Sentiment: Neutral ********
#
# 35****** Live Bullish Tweet Count : 35 ********
# ********Current Number of Bullish Tweets: 35********
# ******** CNN Fear and Greed Index: 44.0 ********
# ******** Total Number of News Crawled: 40 ********
# ******** Sentiment of News: Negative ********
# ******** Current MACD: Sell ********
# ******** Current RSI: Neutral ********
# ******** CURRENT OVERALL SCORE : 29.815789473684212 *****
#
#  Sanctuary Token Airdrop Task Up to155 SNT (~$10) Referral SNT (~$2) Airdrop Link******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 0 ********
# Whos investing in crypto today******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 1 ********
#  For those who are too scared to buy cryptocurrency, try it on LATOKEN app. They provide daily promos from which you can******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 1 ********
#  will always be Relevant******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 2 ********
# I signed up but voyager not available in my state would still love to see $SHIB inu on your car!******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 2 ********
#  Largest Difficulty Adjustment In History Incoming(?)"...relentless selling of late by miners, weak hands,******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 3 ********
#  New airdrop MoonLift (MLTP)Total Reward $2,000 of MLTPRate Market Lbank,Bilaxy,Pancakeswap,Coinmarketcap******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
#  New airdrop MoonLift (MLTP)Total Reward $2,000 of MLTPRate Market Lbank,Bilaxy,Pancakeswap,Coinmarketcap******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
# We have gone trough these point a million times. Peter even provided a list why is superior. You only block and insult the people defending the points. If you actually have real criticism of the points mentioned then speak, otherwise go back to you dark corner.******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
#  has a "Forever September" problem.The philosophy of how and its ecosystem are being built is not accide******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 4 ********
# Facts******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 5 ********
#  First tweet that didnt tank the market******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 5 ********
#  Dont lose sight, bears will receive FTX Trial by Fire******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 5 ********
#  Which strong altcoin will out-perform soon?$eth $ada $egld******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 5 ********
# Bitcoin drops to $46K, altcoins sell-off as report claims Binance is under investigation******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 6 ********
#  I am long term bullish on $BTC and $ETH but it may be time for a big time crash within the crypto field. will one******** Predicted Sentiment: Neutral ********
#
# 35****** Live Bullish Tweet Count : 35 ********
# ********Current Number of Bullish Tweets: 35********
# ******** CNN Fear and Greed Index: 44.0 ********
# ******** Total Number of News Crawled: 39 ********
# ******** Sentiment of News: Negative ********
# ******** Current MACD: Sell ********
# ******** Current RSI: Neutral ********
# ******** CURRENT OVERALL SCORE : 26.042454812946616 *****
#
#  short term holders capitulated yesterday.They took losses on par with all the major drawdowns in bitcoin history. ht******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 1 ********
#  New airdrop MoonLift (MLTP)Total Reward $2,000 of MLTPRate Market Lbank,Bilaxy,Pancakeswap,Coinmarketcap******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 1 ********
#  El Salvador's President has become the first Head of State to reference "sats", the smallest denomination******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 2 ********
#  New airdrop MoonLift (MLTP)Total Reward $2,000 of MLTPRate Market Lbank,Bilaxy,Pancakeswap,Coinmarketcap******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 2 ********
#  We are proud to launch our website! Make sure to check it out. Airdrop and crowd-sale coming soon. Make sure to follow u******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 2 ********
#  Convincing people to buy something by being nice to them is what sales people do. This is a fiat mentality and results in li******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 3 ********
#  New airdrop MoonLift (MLTP)Total Reward $2,000 of MLTPRate Market Lbank,Bilaxy,Pancakeswap,Coinmarketcap******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
#  Coming ID NFT (Today Is Last Day) JUNEDistirbute On JUNeDownload App &amp; Create Chain ID Wallet******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
#  There are only two crypto armies on twitter strong enough to trend big in only minutes. and That******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
#  New  DeFiFarms Reward Up to DEFIY [~$2.2]+3 DEFIY [$0.3] per referral Start the airdrop bot******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 3 ********
# Just leave it there for years and he is gucci******** Predicted Sentiment: Bullish ********
#
# ******** Live Bullish Tweet Count : 4 ********
# guys, don't miss this opportunity, this project will be a great investment for you. ".******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 4 ********
# Irrespective of the price swings, I remain very bullish on the Bitcoin network long-term, due to the fundamentals being stronger than ever. If you are interested, I can teach you how to invest properly and make long-term profits from $BTC &amp; Crypto. Kindly send me a DM******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 4 ********
#  Sanctuary Token Airdrop Task Up to155 SNT (~$10) Referral SNT (~$2) Airdrop Link******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 4 ********
#  HODLers New Investors It's been a wild ride $Btc $Eth******** Predicted Sentiment: Neutral ********
#
# ******** Live Bullish Tweet Count : 4 ********
#  New airdrop MoonLift (MLTP)Total Reward $2,000 of MLTPRate Market Lbank,Bilaxy,Pancakeswap,Coinmarketcap******** Predicted Sentiment: Neutral ********
#
# 35****** Live Bullish Tweet Count : 35 ********
# ********Current Number of Bullish Tweets: 35********
# ******** CNN Fear and Greed Index: 44.0 ********

# %%
# https://algotrading101.com/learn/binance-python-api-guide/

# %%
# https://github.com/labteral/ernie
# ERNIE Algorithm
# Neutral = Bot

# %%
# https://developer.twitter.com/en/docs/twitter-api
